# %%
import zipfile

# Path to the ZIP file and the folder to extract to
zip_file_path = '/content/drive/MyDrive/Speech Emotion Recognition.zip'  # Replace with your ZIP file path
extract_to_folder = '/content/SER'  # Replace with your desired extraction folder

# Extract files
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to_folder)

print(f'Files extracted to {extract_to_folder}')
# Out:
# Files extracted to /content/SER

# %%
import os
import librosa
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.preprocessing import LabelEncoder

# Function to extract features from an audio file
def extract_features(audio_path, max_len=22050*5):  # 5 seconds of audio at 22050Hz
    # Load the audio file
    audio, sample_rate = librosa.load(audio_path, sr=None, duration=5)  # Limit to 5 seconds
    # Ensure consistent length by padding or truncating
    if len(audio) < max_len:
        padding = max_len - len(audio)
        audio = np.pad(audio, (0, padding), 'constant')
    else:
        audio = audio[:max_len]

    # Extract MFCC features
    mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
    mfccs = np.mean(mfccs.T, axis=0)  # Average across time axis

    return mfccs

# Function to load the dataset and extract features
def load_data(dataset_path):
    features = []
    labels = []

    # Iterate through each folder and file
    for label in os.listdir(dataset_path):
        folder_path = os.path.join(dataset_path, label)

        # Only process if it's a folder
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                if file.endswith('.wav'):  # Only process .wav files
                    file_path = os.path.join(folder_path, file)
                    try:
                        mfccs = extract_features(file_path)
                        features.append(mfccs)
                        labels.append(label)
                    except Exception as e:
                        print(f"Error processing {file}: {e}")
                        continue

    return np.array(features), np.array(labels)

# Path to your dataset folder
dataset_path = '/content/SER/Speech Emotion Recognition/TESS Toronto emotional speech set data'

# Load the data
X, y = load_data(dataset_path)

# Encode the labels
label_encoder = LabelEncoder()
y_encoded = to_categorical(label_encoder.fit_transform(y))

# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Reshape features for CNN input (CNN expects 4D input)
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1, 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1, 1)

# %%
# Build a CNN model
model = Sequential()

# Add convolutional layers
model.add(Conv2D(32, (1, 1), activation='relu', padding='same', input_shape=(X_train.shape[1], 1, 1)))  # Kernel size (1,1) for MFCC features
model.add(MaxPooling2D((1, 1)))  # Pooling with (1,1) to avoid reducing dimensions too much
model.add(Dropout(0.3))

model.add(Conv2D(64, (1, 1), activation='relu', padding='same'))
model.add(MaxPooling2D((1, 1)))  # Pooling with (1,1)
model.add(Dropout(0.3))

model.add(Conv2D(128, (1, 1), activation='relu', padding='same'))
model.add(MaxPooling2D((1, 1)))  # Pooling with (1,1)
model.add(Dropout(0.3))

# Flatten the output
model.add(Flatten())

# Add dense layers
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))

# Output layer (adjust output size according to the number of emotions)
num_classes = y_encoded.shape[1]  # Number of unique emotions
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_data=(X_test, y_test))

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_acc:.2f}")

# Save the model for future use
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Define the path in your Google Drive where the model will be saved
model_save_path = '/content/drive/My Drive/speech_emotion_recognition_model.h5'

# Save the model to Google Drive
model.save(model_save_path)

print(f"Model saved to: {model_save_path}")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 0.1031 - loss: 9.5568 - val_accuracy: 0.4411 - val_loss: 2.0153
# Epoch 2/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.3370 - loss: 2.0039 - val_accuracy: 0.9089 - val_loss: 0.3867
# Epoch 3/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6743 - loss: 1.0134 - val_accuracy: 0.9482 - val_loss: 0.1431
# Epoch 4/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7956 - loss: 0.5843 - val_accuracy: 0.9625 - val_loss: 0.1022
# Epoch 5/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8682 - loss: 0.3949 - val_accuracy: 0.9893 - val_loss: 0.0460
# Epoch 6/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8976 - loss: 0.3287 - val_accuracy: 0.9875 - val_loss: 0.0438
# Epoch 7/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9062 - loss: 0.3287 - val_accuracy: 0.9786 - val_loss: 0.0685
# Epoch 8/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9168 - loss: 0.2952 - val_accuracy: 0.9911 - val_loss: 0.0303
# Epoch 9/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9432 - loss: 0.1620 - val_accuracy: 0.9821 - val_loss: 0.0570
# Epoch 10/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9332 - loss: 0.2061 - val_accuracy: 0.9946 - val_loss: 0.0318
# Epoch 11/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9492 - loss: 0.1738 - val_accuracy: 0.9929 - val_loss: 0.0311
# Epoch 12/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9468 - loss: 0.1664 - val_accuracy: 0.9911 - val_loss: 0.0228
# Epoch 13/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9632 - loss: 0.1277 - val_accuracy: 0.9875 - val_loss: 0.0384
# Epoch 14/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9623 - loss: 0.1275 - val_accuracy: 0.9982 - val_loss: 0.0152
# Epoch 15/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9541 - loss: 0.1846 - val_accuracy: 0.9929 - val_loss: 0.0229
# Epoch 16/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9705 - loss: 0.1031 - val_accuracy: 0.9946 - val_loss: 0.0185
# Epoch 17/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9712 - loss: 0.1192 - val_accuracy: 0.9893 - val_loss: 0.0210
# Epoch 18/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9682 - loss: 0.0953 - val_accuracy: 0.9929 - val_loss: 0.0199
# Epoch 19/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9616 - loss: 0.1285 - val_accuracy: 0.9964 - val_loss: 0.0237
# Epoch 20/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9663 - loss: 0.1195 - val_accuracy: 0.9964 - val_loss: 0.0159
# Epoch 21/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9670 - loss: 0.1272 - val_accuracy: 0.9946 - val_loss: 0.0161
# Epoch 22/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9782 - loss: 0.0557 - val_accuracy: 0.9929 - val_loss: 0.0214
# Epoch 23/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9799 - loss: 0.0551 - val_accuracy: 0.9964 - val_loss: 0.0188
# Epoch 24/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9893 - loss: 0.0489 - val_accuracy: 0.9964 - val_loss: 0.0205
# Epoch 25/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9807 - loss: 0.0592 - val_accuracy: 0.9964 - val_loss: 0.0102
# Epoch 26/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9758 - loss: 0.0667 - val_accuracy: 0.9946 - val_loss: 0.0156
# Epoch 27/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9743 - loss: 0.1112 - val_accuracy: 0.9893 - val_loss: 0.0383
# Epoch 28/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9716 - loss: 0.0816 - val_accuracy: 0.9964 - val_loss: 0.0112
# Epoch 29/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9872 - loss: 0.0420 - val_accuracy: 0.9964 - val_loss: 0.0136
# Epoch 30/30
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9767 - loss: 0.0707 - val_accuracy: 1.0000 - val_loss: 0.0070
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0058
# Test Accuracy: 1.00
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Model saved to: /content/drive/My Drive/speech_emotion_recognition_model.h5

# %%
import numpy as np
from sklearn.metrics import classification_report

# Load the trained model
from tensorflow.keras.models import load_model

# Load the model
model = load_model('/content/drive/MyDrive/speech_emotion_recognition_model.h5')

# Make predictions on the test set
predictions = model.predict(X_test)

# Convert predictions from probabilities to class indices
predicted_classes = np.argmax(predictions, axis=1)

# Convert actual labels from one-hot encoding to class indices
actual_classes = np.argmax(y_test, axis=1)

# Decode the labels back to their original form
predicted_labels = label_encoder.inverse_transform(predicted_classes)
actual_labels = label_encoder.inverse_transform(actual_classes)

# Print actual and predicted labels for each sample
print("Actual vs. Predicted Emotions:")
for i in range(len(actual_labels)):
    print(f"Audio {i+1}: Actual = {actual_labels[i]}, Predicted = {predicted_labels[i]}")

# Alternatively, you can use a classification report for a summary
print("\nClassification Report:")
print(classification_report(actual_labels, predicted_labels))
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step
# Actual vs. Predicted Emotions:
# Audio 1: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 2: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 3: Actual = OAF_happy, Predicted = OAF_happy
# Audio 4: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 5: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 6: Actual = OAF_angry, Predicted = OAF_angry
# Audio 7: Actual = YAF_sad, Predicted = YAF_sad
# Audio 8: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 9: Actual = YAF_fear, Predicted = YAF_fear
# Audio 10: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 11: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 12: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 13: Actual = OAF_happy, Predicted = OAF_happy
# Audio 14: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 15: Actual = OAF_happy, Predicted = OAF_happy
# Audio 16: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 17: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 18: Actual = YAF_angry, Predicted = YAF_angry
# Audio 19: Actual = YAF_happy, Predicted = YAF_happy
# Audio 20: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 21: Actual = YAF_sad, Predicted = YAF_sad
# Audio 22: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 23: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 24: Actual = YAF_sad, Predicted = YAF_sad
# Audio 25: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 26: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 27: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 28: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 29: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 30: Actual = YAF_sad, Predicted = YAF_sad
# Audio 31: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 32: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 33: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 34: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 35: Actual = OAF_happy, Predicted = OAF_happy
# Audio 36: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 37: Actual = YAF_happy, Predicted = YAF_happy
# Audio 38: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 39: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 40: Actual = YAF_angry, Predicted = YAF_angry
# Audio 41: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 42: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 43: Actual = OAF_happy, Predicted = OAF_happy
# Audio 44: Actual = YAF_happy, Predicted = YAF_happy
# Audio 45: Actual = YAF_angry, Predicted = YAF_angry
# Audio 46: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 47: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 48: Actual = YAF_fear, Predicted = YAF_fear
# Audio 49: Actual = YAF_sad, Predicted = YAF_sad
# Audio 50: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 51: Actual = OAF_angry, Predicted = OAF_angry
# Audio 52: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 53: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 54: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 55: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 56: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 57: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 58: Actual = YAF_fear, Predicted = YAF_fear
# Audio 59: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 60: Actual = OAF_angry, Predicted = OAF_angry
# Audio 61: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 62: Actual = YAF_sad, Predicted = YAF_sad
# Audio 63: Actual = YAF_angry, Predicted = YAF_angry
# Audio 64: Actual = YAF_fear, Predicted = YAF_fear
# Audio 65: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 66: Actual = YAF_fear, Predicted = YAF_fear
# Audio 67: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 68: Actual = OAF_angry, Predicted = OAF_angry
# Audio 69: Actual = YAF_sad, Predicted = YAF_sad
# Audio 70: Actual = OAF_happy, Predicted = OAF_happy
# Audio 71: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 72: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 73: Actual = OAF_angry, Predicted = OAF_angry
# Audio 74: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 75: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 76: Actual = YAF_angry, Predicted = YAF_angry
# Audio 77: Actual = YAF_fear, Predicted = YAF_fear
# Audio 78: Actual = YAF_angry, Predicted = YAF_angry
# Audio 79: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 80: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 81: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 82: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 83: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 84: Actual = YAF_sad, Predicted = YAF_sad
# Audio 85: Actual = YAF_angry, Predicted = YAF_angry
# Audio 86: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 87: Actual = OAF_angry, Predicted = OAF_angry
# Audio 88: Actual = YAF_happy, Predicted = YAF_happy
# Audio 89: Actual = YAF_angry, Predicted = YAF_angry
# Audio 90: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 91: Actual = YAF_happy, Predicted = YAF_happy
# Audio 92: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 93: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 94: Actual = YAF_fear, Predicted = YAF_fear
# Audio 95: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 96: Actual = YAF_angry, Predicted = YAF_angry
# Audio 97: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 98: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 99: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 100: Actual = OAF_happy, Predicted = OAF_happy
# Audio 101: Actual = OAF_happy, Predicted = OAF_happy
# Audio 102: Actual = YAF_sad, Predicted = YAF_sad
# Audio 103: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 104: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 105: Actual = YAF_sad, Predicted = YAF_sad
# Audio 106: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 107: Actual = YAF_sad, Predicted = YAF_sad
# Audio 108: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 109: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 110: Actual = YAF_angry, Predicted = YAF_angry
# Audio 111: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 112: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 113: Actual = YAF_fear, Predicted = YAF_fear
# Audio 114: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 115: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 116: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 117: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 118: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 119: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 120: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 121: Actual = OAF_happy, Predicted = OAF_happy
# Audio 122: Actual = YAF_angry, Predicted = YAF_angry
# Audio 123: Actual = YAF_fear, Predicted = YAF_fear
# Audio 124: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 125: Actual = OAF_happy, Predicted = OAF_happy
# Audio 126: Actual = YAF_sad, Predicted = YAF_sad
# Audio 127: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 128: Actual = YAF_sad, Predicted = YAF_sad
# Audio 129: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 130: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 131: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 132: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 133: Actual = YAF_happy, Predicted = YAF_happy
# Audio 134: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 135: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 136: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 137: Actual = OAF_happy, Predicted = OAF_happy
# Audio 138: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 139: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 140: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 141: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 142: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 143: Actual = YAF_fear, Predicted = YAF_fear
# Audio 144: Actual = YAF_fear, Predicted = YAF_fear
# Audio 145: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 146: Actual = YAF_sad, Predicted = YAF_sad
# Audio 147: Actual = YAF_fear, Predicted = YAF_fear
# Audio 148: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 149: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 150: Actual = OAF_happy, Predicted = OAF_happy
# Audio 151: Actual = YAF_angry, Predicted = YAF_angry
# Audio 152: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 153: Actual = YAF_fear, Predicted = YAF_fear
# Audio 154: Actual = YAF_sad, Predicted = YAF_sad
# Audio 155: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 156: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 157: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 158: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 159: Actual = OAF_happy, Predicted = OAF_happy
# Audio 160: Actual = OAF_angry, Predicted = OAF_angry
# Audio 161: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 162: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 163: Actual = YAF_fear, Predicted = YAF_fear
# Audio 164: Actual = YAF_happy, Predicted = YAF_happy
# Audio 165: Actual = OAF_angry, Predicted = OAF_angry
# Audio 166: Actual = OAF_angry, Predicted = OAF_angry
# Audio 167: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 168: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 169: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 170: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 171: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 172: Actual = OAF_angry, Predicted = OAF_angry
# Audio 173: Actual = OAF_angry, Predicted = OAF_angry
# Audio 174: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 175: Actual = OAF_angry, Predicted = OAF_angry
# Audio 176: Actual = OAF_happy, Predicted = OAF_happy
# Audio 177: Actual = YAF_fear, Predicted = YAF_fear
# Audio 178: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 179: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 180: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 181: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 182: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 183: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 184: Actual = OAF_happy, Predicted = OAF_happy
# Audio 185: Actual = YAF_sad, Predicted = YAF_sad
# Audio 186: Actual = YAF_angry, Predicted = YAF_angry
# Audio 187: Actual = YAF_angry, Predicted = YAF_angry
# Audio 188: Actual = OAF_angry, Predicted = OAF_angry
# Audio 189: Actual = YAF_fear, Predicted = YAF_fear
# Audio 190: Actual = YAF_happy, Predicted = YAF_happy
# Audio 191: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 192: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 193: Actual = YAF_happy, Predicted = YAF_happy
# Audio 194: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 195: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 196: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 197: Actual = YAF_sad, Predicted = YAF_sad
# Audio 198: Actual = YAF_fear, Predicted = YAF_fear
# Audio 199: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 200: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 201: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 202: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 203: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 204: Actual = YAF_angry, Predicted = YAF_angry
# Audio 205: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 206: Actual = YAF_angry, Predicted = YAF_angry
# Audio 207: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 208: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 209: Actual = OAF_happy, Predicted = OAF_happy
# Audio 210: Actual = YAF_fear, Predicted = YAF_fear
# Audio 211: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 212: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 213: Actual = OAF_happy, Predicted = OAF_happy
# Audio 214: Actual = YAF_sad, Predicted = YAF_sad
# Audio 215: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 216: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 217: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 218: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 219: Actual = YAF_sad, Predicted = YAF_sad
# Audio 220: Actual = YAF_sad, Predicted = YAF_sad
# Audio 221: Actual = YAF_angry, Predicted = YAF_angry
# Audio 222: Actual = YAF_happy, Predicted = YAF_happy
# Audio 223: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 224: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 225: Actual = OAF_happy, Predicted = OAF_happy
# Audio 226: Actual = YAF_sad, Predicted = YAF_sad
# Audio 227: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 228: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 229: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 230: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 231: Actual = YAF_sad, Predicted = YAF_sad
# Audio 232: Actual = YAF_sad, Predicted = YAF_sad
# Audio 233: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 234: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 235: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 236: Actual = YAF_happy, Predicted = YAF_happy
# Audio 237: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 238: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 239: Actual = OAF_happy, Predicted = OAF_happy
# Audio 240: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 241: Actual = YAF_sad, Predicted = YAF_sad
# Audio 242: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 243: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 244: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 245: Actual = OAF_angry, Predicted = OAF_angry
# Audio 246: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 247: Actual = OAF_angry, Predicted = OAF_angry
# Audio 248: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 249: Actual = YAF_sad, Predicted = YAF_sad
# Audio 250: Actual = YAF_fear, Predicted = YAF_fear
# Audio 251: Actual = OAF_happy, Predicted = OAF_happy
# Audio 252: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 253: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 254: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 255: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 256: Actual = YAF_happy, Predicted = YAF_happy
# Audio 257: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 258: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 259: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 260: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 261: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 262: Actual = YAF_fear, Predicted = YAF_fear
# Audio 263: Actual = YAF_happy, Predicted = YAF_happy
# Audio 264: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 265: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 266: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 267: Actual = YAF_happy, Predicted = YAF_happy
# Audio 268: Actual = YAF_sad, Predicted = YAF_sad
# Audio 269: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 270: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 271: Actual = OAF_happy, Predicted = OAF_happy
# Audio 272: Actual = OAF_angry, Predicted = OAF_angry
# Audio 273: Actual = YAF_fear, Predicted = YAF_fear
# Audio 274: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 275: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 276: Actual = YAF_angry, Predicted = YAF_angry
# Audio 277: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 278: Actual = YAF_angry, Predicted = YAF_angry
# Audio 279: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 280: Actual = YAF_sad, Predicted = YAF_sad
# Audio 281: Actual = YAF_fear, Predicted = YAF_fear
# Audio 282: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 283: Actual = YAF_sad, Predicted = YAF_sad
# Audio 284: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 285: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 286: Actual = YAF_happy, Predicted = YAF_happy
# Audio 287: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 288: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 289: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 290: Actual = YAF_fear, Predicted = YAF_fear
# Audio 291: Actual = YAF_happy, Predicted = YAF_happy
# Audio 292: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 293: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 294: Actual = YAF_fear, Predicted = YAF_fear
# Audio 295: Actual = YAF_sad, Predicted = YAF_sad
# Audio 296: Actual = OAF_angry, Predicted = OAF_angry
# Audio 297: Actual = YAF_fear, Predicted = YAF_fear
# Audio 298: Actual = YAF_fear, Predicted = YAF_fear
# Audio 299: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 300: Actual = OAF_angry, Predicted = OAF_angry
# Audio 301: Actual = YAF_fear, Predicted = YAF_fear
# Audio 302: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 303: Actual = OAF_happy, Predicted = OAF_happy
# Audio 304: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 305: Actual = YAF_fear, Predicted = YAF_fear
# Audio 306: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 307: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 308: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 309: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 310: Actual = YAF_fear, Predicted = YAF_fear
# Audio 311: Actual = YAF_happy, Predicted = YAF_happy
# Audio 312: Actual = YAF_fear, Predicted = YAF_fear
# Audio 313: Actual = OAF_happy, Predicted = OAF_happy
# Audio 314: Actual = YAF_angry, Predicted = YAF_angry
# Audio 315: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 316: Actual = OAF_angry, Predicted = OAF_angry
# Audio 317: Actual = YAF_happy, Predicted = YAF_happy
# Audio 318: Actual = OAF_angry, Predicted = OAF_angry
# Audio 319: Actual = YAF_sad, Predicted = YAF_sad
# Audio 320: Actual = OAF_happy, Predicted = OAF_happy
# Audio 321: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 322: Actual = OAF_happy, Predicted = OAF_happy
# Audio 323: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 324: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 325: Actual = YAF_sad, Predicted = YAF_sad
# Audio 326: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 327: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 328: Actual = OAF_happy, Predicted = OAF_happy
# Audio 329: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 330: Actual = YAF_fear, Predicted = YAF_fear
# Audio 331: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 332: Actual = YAF_happy, Predicted = YAF_happy
# Audio 333: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 334: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 335: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 336: Actual = YAF_sad, Predicted = YAF_sad
# Audio 337: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 338: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 339: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 340: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 341: Actual = YAF_happy, Predicted = YAF_happy
# Audio 342: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 343: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 344: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 345: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 346: Actual = YAF_happy, Predicted = YAF_happy
# Audio 347: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 348: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 349: Actual = OAF_angry, Predicted = OAF_angry
# Audio 350: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 351: Actual = YAF_sad, Predicted = YAF_sad
# Audio 352: Actual = YAF_fear, Predicted = YAF_fear
# Audio 353: Actual = YAF_sad, Predicted = YAF_sad
# Audio 354: Actual = YAF_happy, Predicted = YAF_happy
# Audio 355: Actual = YAF_angry, Predicted = YAF_angry
# Audio 356: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 357: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 358: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 359: Actual = OAF_angry, Predicted = OAF_angry
# Audio 360: Actual = OAF_happy, Predicted = OAF_happy
# Audio 361: Actual = YAF_angry, Predicted = YAF_angry
# Audio 362: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 363: Actual = YAF_sad, Predicted = YAF_sad
# Audio 364: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 365: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 366: Actual = YAF_sad, Predicted = YAF_sad
# Audio 367: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 368: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 369: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 370: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 371: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 372: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 373: Actual = YAF_happy, Predicted = YAF_happy
# Audio 374: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 375: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 376: Actual = YAF_happy, Predicted = YAF_happy
# Audio 377: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 378: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 379: Actual = YAF_fear, Predicted = YAF_fear
# Audio 380: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 381: Actual = OAF_angry, Predicted = OAF_angry
# Audio 382: Actual = OAF_happy, Predicted = OAF_happy
# Audio 383: Actual = YAF_fear, Predicted = YAF_fear
# Audio 384: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 385: Actual = OAF_happy, Predicted = OAF_happy
# Audio 386: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 387: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 388: Actual = YAF_happy, Predicted = YAF_happy
# Audio 389: Actual = YAF_sad, Predicted = YAF_sad
# Audio 390: Actual = YAF_angry, Predicted = YAF_angry
# Audio 391: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 392: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 393: Actual = OAF_angry, Predicted = OAF_angry
# Audio 394: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 395: Actual = OAF_angry, Predicted = OAF_angry
# Audio 396: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 397: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 398: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 399: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 400: Actual = YAF_happy, Predicted = YAF_happy
# Audio 401: Actual = YAF_happy, Predicted = YAF_happy
# Audio 402: Actual = YAF_fear, Predicted = YAF_fear
# Audio 403: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 404: Actual = OAF_angry, Predicted = OAF_angry
# Audio 405: Actual = OAF_angry, Predicted = OAF_angry
# Audio 406: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 407: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 408: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 409: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 410: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 411: Actual = YAF_angry, Predicted = YAF_angry
# Audio 412: Actual = YAF_sad, Predicted = YAF_sad
# Audio 413: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 414: Actual = OAF_happy, Predicted = OAF_happy
# Audio 415: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 416: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 417: Actual = YAF_sad, Predicted = YAF_sad
# Audio 418: Actual = YAF_angry, Predicted = YAF_angry
# Audio 419: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 420: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 421: Actual = YAF_fear, Predicted = YAF_fear
# Audio 422: Actual = OAF_happy, Predicted = OAF_happy
# Audio 423: Actual = YAF_angry, Predicted = YAF_angry
# Audio 424: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 425: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 426: Actual = YAF_fear, Predicted = YAF_fear
# Audio 427: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 428: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 429: Actual = YAF_happy, Predicted = YAF_happy
# Audio 430: Actual = YAF_happy, Predicted = YAF_happy
# Audio 431: Actual = YAF_fear, Predicted = YAF_fear
# Audio 432: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 433: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 434: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 435: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 436: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 437: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 438: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 439: Actual = OAF_angry, Predicted = OAF_angry
# Audio 440: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 441: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 442: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 443: Actual = YAF_angry, Predicted = YAF_angry
# Audio 444: Actual = OAF_angry, Predicted = OAF_angry
# Audio 445: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 446: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 447: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 448: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 449: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 450: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 451: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 452: Actual = YAF_sad, Predicted = YAF_sad
# Audio 453: Actual = YAF_happy, Predicted = YAF_happy
# Audio 454: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 455: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 456: Actual = YAF_fear, Predicted = YAF_fear
# Audio 457: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 458: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 459: Actual = YAF_happy, Predicted = YAF_happy
# Audio 460: Actual = OAF_happy, Predicted = OAF_happy
# Audio 461: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 462: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 463: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 464: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 465: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 466: Actual = YAF_happy, Predicted = YAF_happy
# Audio 467: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 468: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 469: Actual = OAF_happy, Predicted = OAF_happy
# Audio 470: Actual = OAF_angry, Predicted = OAF_angry
# Audio 471: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 472: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 473: Actual = YAF_sad, Predicted = YAF_sad
# Audio 474: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 475: Actual = YAF_angry, Predicted = YAF_angry
# Audio 476: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 477: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 478: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 479: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 480: Actual = YAF_sad, Predicted = YAF_sad
# Audio 481: Actual = YAF_fear, Predicted = YAF_fear
# Audio 482: Actual = YAF_angry, Predicted = YAF_angry
# Audio 483: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 484: Actual = OAF_angry, Predicted = OAF_angry
# Audio 485: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 486: Actual = YAF_sad, Predicted = YAF_sad
# Audio 487: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 488: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 489: Actual = OAF_angry, Predicted = OAF_angry
# Audio 490: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 491: Actual = OAF_angry, Predicted = OAF_angry
# Audio 492: Actual = YAF_angry, Predicted = YAF_angry
# Audio 493: Actual = YAF_happy, Predicted = YAF_happy
# Audio 494: Actual = YAF_sad, Predicted = YAF_sad
# Audio 495: Actual = YAF_happy, Predicted = YAF_happy
# Audio 496: Actual = YAF_sad, Predicted = YAF_sad
# Audio 497: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 498: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 499: Actual = YAF_happy, Predicted = YAF_happy
# Audio 500: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 501: Actual = YAF_happy, Predicted = YAF_happy
# Audio 502: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 503: Actual = YAF_fear, Predicted = YAF_fear
# Audio 504: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 505: Actual = OAF_angry, Predicted = OAF_angry
# Audio 506: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 507: Actual = YAF_fear, Predicted = YAF_fear
# Audio 508: Actual = OAF_angry, Predicted = OAF_angry
# Audio 509: Actual = YAF_sad, Predicted = YAF_sad
# Audio 510: Actual = YAF_sad, Predicted = YAF_sad
# Audio 511: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 512: Actual = YAF_angry, Predicted = YAF_angry
# Audio 513: Actual = OAF_happy, Predicted = OAF_happy
# Audio 514: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 515: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 516: Actual = OAF_happy, Predicted = OAF_happy
# Audio 517: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 518: Actual = YAF_happy, Predicted = YAF_happy
# Audio 519: Actual = YAF_sad, Predicted = YAF_sad
# Audio 520: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 521: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 522: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 523: Actual = YAF_sad, Predicted = YAF_sad
# Audio 524: Actual = YAF_angry, Predicted = YAF_angry
# Audio 525: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 526: Actual = OAF_happy, Predicted = OAF_happy
# Audio 527: Actual = OAF_angry, Predicted = OAF_angry
# Audio 528: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 529: Actual = OAF_happy, Predicted = OAF_happy
# Audio 530: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 531: Actual = YAF_pleasant_surprised, Predicted = YAF_pleasant_surprised
# Audio 532: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 533: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 534: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 535: Actual = YAF_angry, Predicted = YAF_angry
# Audio 536: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 537: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 538: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 539: Actual = OAF_angry, Predicted = OAF_angry
# Audio 540: Actual = YAF_disgust, Predicted = YAF_disgust
# Audio 541: Actual = OAF_Sad, Predicted = OAF_Sad
# Audio 542: Actual = YAF_happy, Predicted = YAF_happy
# Audio 543: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 544: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 545: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 546: Actual = OAF_neutral, Predicted = OAF_neutral
# Audio 547: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 548: Actual = YAF_happy, Predicted = YAF_happy
# Audio 549: Actual = OAF_angry, Predicted = OAF_angry
# Audio 550: Actual = YAF_neutral, Predicted = YAF_neutral
# Audio 551: Actual = OAF_angry, Predicted = OAF_angry
# Audio 552: Actual = OAF_happy, Predicted = OAF_happy
# Audio 553: Actual = OAF_disgust, Predicted = OAF_disgust
# Audio 554: Actual = OAF_happy, Predicted = OAF_happy
# Audio 555: Actual = OAF_happy, Predicted = OAF_happy
# Audio 556: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 557: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 558: Actual = OAF_Pleasant_surprise, Predicted = OAF_Pleasant_surprise
# Audio 559: Actual = OAF_Fear, Predicted = OAF_Fear
# Audio 560: Actual = YAF_fear, Predicted = YAF_fear
#
# Classification Report:
#                         precision    recall  f1-score   support
#
#               OAF_Fear       1.00      1.00      1.00        37
#  OAF_Pleasant_surprise       1.00      1.00      1.00        47
#                OAF_Sad       1.00      1.00      1.00        30
#              OAF_angry       1.00      1.00      1.00        39
#            OAF_disgust       1.00      1.00      1.00        40
#              OAF_happy       1.00      1.00      1.00        40
#            OAF_neutral       1.00      1.00      1.00        37
#              YAF_angry       1.00      1.00      1.00        33
#            YAF_disgust       1.00      1.00      1.00        52
#               YAF_fear       1.00      1.00      1.00        43
#              YAF_happy       1.00      1.00      1.00        39
#            YAF_neutral       1.00      1.00      1.00        37
# YAF_pleasant_surprised       1.00      1.00      1.00        37
#                YAF_sad       1.00      1.00      1.00        49
#
#               accuracy                           1.00       560
#              macro avg       1.00      1.00      1.00       560
#           weighted avg       1.00      1.00      1.00       560
